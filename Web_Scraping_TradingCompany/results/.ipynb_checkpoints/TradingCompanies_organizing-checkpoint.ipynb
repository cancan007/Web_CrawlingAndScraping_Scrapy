# %%
import numpy as np
import pandas as  pd
import matplotlib.pyplot as plt
from warnings import filterwarnings
from mpl_toolkits.mplot3d import Axes3D
import statsmodels.api as sm
import missingno as msno
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from sklearn.neighbors import LocalOutlierFactor
from scipy.stats import levene
from scipy.stats import shapiro
from scipy.stats.stats import pearsonr
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict, ShuffleSplit, GridSearchCV 
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import model_selection
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import BaggingRegressor
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LinearRegression
from sklearn.cross_decomposition import PLSRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import Lasso
from sklearn.linear_model import LassoCV
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import ElasticNetCV
from sklearn import linear_model
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
import xgboost as xgb
from xgboost import XGBRegressor, XGBClassifier
from lightgbm import LGBMRegressor, LGBMClassifier
from catboost import CatBoostRegressor, CatBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn import tree
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, roc_auc_score, roc_curve
import seaborn as sns

# %%
pip install googletrans==4.0.0-rc1
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from googletrans import Translator #グーグル翻訳を使えるようになる

# %%
import time

# %%
data = pd.read_csv(r"C:\Users\shota\Web_Scraping_TradingCompany\results\Trading_Companies.csv")
data
# Out:
#               Company                                        Description  \
# 0          株式会社ＳＵＺＵＫＩ  \n                  「ソリオ」「アルト」シリーズなどの自動車や自動二輪車...
# 1            株式会社ＪＥＲＡ  \n                  国内外にて石炭貿易や火力発電を行う会社\n     ...
# 2            豊田通商株式会社  \n                  金属分野やグローバル部品・ロジスティクス分野などのト...
# 3            東洋冷蔵株式会社  \n                  マグロやサケ・エビ等水産物の養殖及び加工・輸入を行う...
# 4    郵船コーディアルサービス株式会社  \n                  人材派遣や海運代理店業などを行っている会社\n   ...
# ..                ...                                                ...
# 937   メディアトレーディング株式会社  \n                  Webサイト制作やシステム開発および包装資材の貿易を...
# 938     ジェームストランス株式会社  \n                  日本韓国間を中心に海上輸送や航空輸送を行う会社\n ...
# 939          錦南商事株式会社  \n                  韓国産を主とした鮮魚およびチャンジャなどの輸入を行う...
# 940        株式会社ベリーベリー  \n                  中国越境ECなど日本製品の中国市場への卸販売を行う会...
# 941           ＷＲＢ株式会社  \n                  太陽光発電用地への投資や太陽光発電所の運営などを行う...
#
#           Industry                                           Location  \
# ...

# %%
translator = Translator()

# %%
data1 = data
data1.dropna(how='any', inplace=True)
data1
# Out:
#               Company                                        Description  \
# 0          株式会社ＳＵＺＵＫＩ  \n                  「ソリオ」「アルト」シリーズなどの自動車や自動二輪車...
# 1            株式会社ＪＥＲＡ  \n                  国内外にて石炭貿易や火力発電を行う会社\n     ...
# 2            豊田通商株式会社  \n                  金属分野やグローバル部品・ロジスティクス分野などのト...
# 3            東洋冷蔵株式会社  \n                  マグロやサケ・エビ等水産物の養殖及び加工・輸入を行う...
# 4    郵船コーディアルサービス株式会社  \n                  人材派遣や海運代理店業などを行っている会社\n   ...
# ..                ...                                                ...
# 937   メディアトレーディング株式会社  \n                  Webサイト制作やシステム開発および包装資材の貿易を...
# 938     ジェームストランス株式会社  \n                  日本韓国間を中心に海上輸送や航空輸送を行う会社\n ...
# 939          錦南商事株式会社  \n                  韓国産を主とした鮮魚およびチャンジャなどの輸入を行う...
# 940        株式会社ベリーベリー  \n                  中国越境ECなど日本製品の中国市場への卸販売を行う会...
# 941           ＷＲＢ株式会社  \n                  太陽光発電用地への投資や太陽光発電所の運営などを行う...
#
#           Industry                                           Location  \
# ...

# %%
translator.raise_Exception = True

# %%
#industries = [translator.translate(i).text for i in data['Industry']]
#industries

# %%
industries = []
for i in data['Industry']:
    ind = translator.translate(i).text
    time.sleep(1)
    industries.append(ind)

# %%
#descriptions = [translator.translate(i).text for i in data['Description']]

# %%
descriptions = []
for d in data['Description']:
    de = translator.translate(d).text
    time.sleep(0.5)
    descriptions.append(de)

# %%
locations = []
for l in data['Location']:
    loc = translator.translate(l).text
    time.sleep(0.5)
    locations.append(loc)

# %%
dataV = data.copy()
dataV['Industry'] = industries
dataV['Description'] = descriptions
dataV['Location'] = locations
dataV = dataV[['Company', 'Industry', 'Location', 'Description', 'URL']]
dataV
# Out:
#               Company                                         Industry  \
# 0          株式会社ＳＵＺＵＫＩ             Automobile and ride industry company
# 1            株式会社ＪＥＲＡ      Machine Related Services Industry Companies
# 2            豊田通商株式会社      Machine Related Services Industry Companies
# 3            東洋冷蔵株式会社                            Food industry company
# 4    郵船コーディアルサービス株式会社                 Human resources industry company
# ..                ...                                              ...
# 937   メディアトレーディング株式会社                      Consulting industry company
# 938     ジェームストランス株式会社  Transportation and logistics industry companies
# 939          錦南商事株式会社                          Retail industry company
# 940        株式会社ベリーベリー                            Food industry company
# 941           ＷＲＢ株式会社                       Financial industry company
#
#                                               Location  \
# 0    Headquarters Address: 1 of Kamo-gun, Shizuoka ...
# ...

# %%
dataV2 = dataV.copy()
dataV2 = dataV2.sort_values(by=['Industry','Location']).reset_index(drop=True)
dataV2
# Out:
#             Company                                         Industry  \
# 0           株式会社日中社                     Advertising industry company
# 1          丸正通商株式会社                     Advertising industry company
# 2     株式会社ファーストペンギン                     Advertising industry company
# 3            株式会社千寿                     Advertising industry company
# 4         株式会社フィールド                     Advertising industry company
# ..              ...                                              ...
# 937  テイエスエルタンカー株式会社  Transportation and logistics industry companies
# 938   北陸ポートサービス株式会社  Transportation and logistics industry companies
# 939   株式会社ユーユープロダクツ  Transportation and logistics industry companies
# 940        株式会社鴻洋通商  Transportation and logistics industry companies
# 941      株式会社パシフィック  Transportation and logistics industry companies
#
#                                               Location  \
# 0    Headquarters Address: 16th NAS Building, Kanda...
# ...

# %%
#dataV2.to_csv('TradingCompanies.csv', index=False)
#dataV2.to_excel('TradingCompanies.xlsx', index=False)

# %%
dataV2['Location'] = [i.replace('Headquarters Address: ','') for i in dataV2['Location']]
dataV2 = dataV2.sort_values(by=['Industry','Location']).reset_index(drop=True)
dataV2
# Out:
#             Company                                         Industry  \
# 0           株式会社日中社                     Advertising industry company
# 1          丸正通商株式会社                     Advertising industry company
# 2     株式会社ファーストペンギン                     Advertising industry company
# 3            株式会社千寿                     Advertising industry company
# 4         株式会社フィールド                     Advertising industry company
# ..              ...                                              ...
# 937  テイエスエルタンカー株式会社  Transportation and logistics industry companies
# 938   北陸ポートサービス株式会社  Transportation and logistics industry companies
# 939   株式会社ユーユープロダクツ  Transportation and logistics industry companies
# 940        株式会社鴻洋通商  Transportation and logistics industry companies
# 941      株式会社パシフィック  Transportation and logistics industry companies
#
#                                               Location  \
# 0      16th NAS Building, Kanda-cho, Chiyoda-ku, Tokyo
# ...

# %%
dataV2['URL'] = [u.replace('/companies/keyword/2a970ee1-15a7-45e0-b1eb-37e738712447', '') for u in dataV2['URL']]
dataV2
# Out:
#             Company                                         Industry  \
# 0           株式会社日中社                     Advertising industry company
# 1          丸正通商株式会社                     Advertising industry company
# 2     株式会社ファーストペンギン                     Advertising industry company
# 3            株式会社千寿                     Advertising industry company
# 4         株式会社フィールド                     Advertising industry company
# ..              ...                                              ...
# 937  テイエスエルタンカー株式会社  Transportation and logistics industry companies
# 938   北陸ポートサービス株式会社  Transportation and logistics industry companies
# 939   株式会社ユーユープロダクツ  Transportation and logistics industry companies
# 940        株式会社鴻洋通商  Transportation and logistics industry companies
# 941      株式会社パシフィック  Transportation and logistics industry companies
#
#                                               Location  \
# 0      16th NAS Building, Kanda-cho, Chiyoda-ku, Tokyo
# ...

# %%
dataV2.to_excel('Trading_Companies.xlsx', index=False)
