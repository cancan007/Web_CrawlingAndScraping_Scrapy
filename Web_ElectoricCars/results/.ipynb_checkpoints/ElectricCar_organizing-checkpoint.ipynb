# %%
import numpy as np
import pandas as  pd
import matplotlib.pyplot as plt
from warnings import filterwarnings
from mpl_toolkits.mplot3d import Axes3D
import statsmodels.api as sm
import missingno as msno
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from sklearn.neighbors import LocalOutlierFactor
from scipy.stats import levene
from scipy.stats import shapiro
from scipy.stats.stats import pearsonr
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict, ShuffleSplit, GridSearchCV 
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import model_selection
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import BaggingRegressor
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LinearRegression
from sklearn.cross_decomposition import PLSRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import Lasso
from sklearn.linear_model import LassoCV
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import ElasticNetCV
from sklearn import linear_model
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
import xgboost as xgb
from xgboost import XGBRegressor, XGBClassifier
from lightgbm import LGBMRegressor, LGBMClassifier
from catboost import CatBoostRegressor, CatBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn import tree
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, roc_auc_score, roc_curve
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\shota\Web_ElectoricCars\results\electric_cars8.csv")
data
# Out:
#    BrandNewCarPrice            CarName  \
# 0           261～295                オーラ
# 1           202～244        ノート e-POWER
# 2           299～380        セレナ e-POWER
# 3           275～286       キックス e-POWER
# 4           660～790                アリア
# 5           177～308        ノート e-POWER
# 6           255～435                208
# 7           444～717               モデル3
# 8           332～499                リーフ
# 9           306～477           SUV 2008
# 10          242～495              MX-30
# 11          273～456                リーフ
# 12              NaN               モデルY
# 13        1169～1799               モデルS
# 14          640～790                EQA
# 15          226～398             i-MiEV
# 16          710～860        MIRAI (ミライ)
# 17          520～732     DS 7 CROSSBACK
# 18          199～368                208
# 19        1269～1499               モデルX
# 20          505～616                 i3
# 21          451～495            Honda e
# 22          392～534     DS 3 CROSSBACK
# ...

# %%
data.columns
# Out:
# Index(['BrandNewCarPrice', 'CarName', 'URL', 'UsedCarPrice'], dtype='object')

# %%
data['Ranking'] = data.index + 1
dataN = data[['Ranking', 'CarName', 'BrandNewCarPrice', 'UsedCarPrice', 'URL']]
dataN['BrandNewCarPrice[TenThousand_yen]'] = dataN['BrandNewCarPrice']
dataN['UsedCarPrice[TenThousand_yen]'] = dataN['UsedCarPrice']
dataN = dataN[['Ranking', 'CarName', 'BrandNewCarPrice[TenThousand_yen]', 'UsedCarPrice[TenThousand_yen]', 'URL']]
dataN
# Out:
# <ipython-input-5-812c9512b0bf>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataN['BrandNewCarPrice[TenThousand_yen]'] = dataN['BrandNewCarPrice']
# <ipython-input-5-812c9512b0bf>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataN['UsedCarPrice[TenThousand_yen]'] = dataN['UsedCarPrice']
#     Ranking            CarName BrandNewCarPrice[TenThousand_yen]  \
# 0         1                オーラ                           261～295
# ...

# %%
dataN['URL'] = [i.replace('/kuruma/ranking/fueltype=electric-car', '') for i in dataN['URL']]
dataN
# Out:
#     Ranking            CarName BrandNewCarPrice[TenThousand_yen]  \
# 0         1                オーラ                           261～295
# 1         2        ノート e-POWER                           202～244
# 2         3        セレナ e-POWER                           299～380
# 3         4       キックス e-POWER                           275～286
# 4         5                アリア                           660～790
# 5         6        ノート e-POWER                           177～308
# 6         7                208                           255～435
# 7         8               モデル3                           444～717
# 8         9                リーフ                           332～499
# 9        10           SUV 2008                           306～477
# 10       11              MX-30                           242～495
# 11       12                リーフ                           273～456
# 12       13               モデルY                               NaN
# ...

# %%
dataN.to_excel('ElectricCars.xlsx', index=False)
