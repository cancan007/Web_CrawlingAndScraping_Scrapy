# %%
import numpy as np
import pandas as  pd
import matplotlib.pyplot as plt
from warnings import filterwarnings
from mpl_toolkits.mplot3d import Axes3D
import statsmodels.api as sm
import missingno as msno
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
from sklearn.neighbors import LocalOutlierFactor
from scipy.stats import levene
from scipy.stats import shapiro
from scipy.stats.stats import pearsonr
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score, cross_val_predict, ShuffleSplit, GridSearchCV 
from sklearn.metrics import mean_squared_error, r2_score
from sklearn import model_selection
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import BaggingRegressor
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.neural_network import MLPRegressor
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LinearRegression
from sklearn.cross_decomposition import PLSRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import RidgeCV
from sklearn.linear_model import Lasso
from sklearn.linear_model import LassoCV
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import ElasticNetCV
from sklearn import linear_model
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.ensemble import GradientBoostingRegressor, GradientBoostingClassifier
import xgboost as xgb
from xgboost import XGBRegressor, XGBClassifier
from lightgbm import LGBMRegressor, LGBMClassifier
from catboost import CatBoostRegressor, CatBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn import tree
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, roc_auc_score, roc_curve
import seaborn as sns

# %%
data = pd.read_csv(r'C:\Users\shota\Web_UKPrograms\results\UKPrograms3.csv')
data
# Out:
#                    EducationLevel                     Location      Method  \
# 0                 Master's degree      \t\tDorset, England\r\n   On campus
# 1               Bachelor's degree  \t\tCanterbury, England\r\n   On campus
# 2               Bachelor's degree      \t\tLondon, England\r\n   On campus
# 3    Foundation / Pathway program  \t\tBirmingham, England\r\n   On campus
# 4               Bachelor's degree    \t\tCornwall, England\r\n   On campus
# ..                            ...                          ...         ...
# 723             Bachelor's degree      \t\tLondon, England\r\n   On campus
# 724  Foundation / Pathway program   \t\tSheffield, England\r\n   On campus
# 725             Bachelor's degree      \t\tLondon, England\r\n   On campus
# 726  Foundation / Pathway program      \t\tLondon, England\r\n   On campus
# 727  Foundation / Pathway program      \t\tLondon, England\r\n   On campus
#
#                                                Program     Term  \
# ...

# %%
data.columns
# Out:
# Index(['EducationLevel', 'Location', 'Method', 'Program', 'Term', 'URL',
#        'University'],
#       dtype='object')

# %%
dataV = data.copy()

# %%
dataV = dataV[['Program','Term', 'University', 'Location' ,'EducationLevel', 'Method', 'URL']]
dataV
# Out:
#                                                Program     Term  \
# 0                          Tourism Management (Taught)  2 years
# 1                                   Tourism Management  3 years
# 2    Tourism and Travel Management (Top-up) BA (Ful...   1 year
# 3                   Tourism and Hospitality Management  2 years
# 4                 Creative Events Management BA (Hons)  3 years
# ..                                                 ...      ...
# 723         Baking Science and Technology (Management)  3 years
# 724                   Bakery and Patisserie Technology  2 years
# 725      Baking Science Technology (Management) Top-Up   1 year
# 726          Baking Science and Technology (Nutrition)  2 years
# 727                      Baking Science and Technology  2 years
#
#                               University                     Location  \
# 0                 Bournemouth University      \t\tDorset, England\r\n
# ...

# %%
dataV2 = dataV.sort_values(by=['Term','University', 'Location']).reset_index(drop=True)
dataV2
# Out:
#                                                Program    Term  \
# 0    International Hospitality and Tourism Manageme...  1 year
# 1              Travel and Tourism Management - Bedford  1 year
# 2                 Luxury Jewellery Management (Taught)  1 year
# 3    Event, Festival and Exhibition Management (Tau...  1 year
# 4                      Hospitality Management (Top-Up)  1 year
# ..                                                 ...     ...
# 723                          Hospitality Management BA     NaN
# 724             BA (Hons) Event and Tourism Management     NaN
# 725                         BA (Hons) Event Management     NaN
# 726                                 Tourism Management     NaN
# 727  International Hospitality Management with Digi...     NaN
#
#                      University                              Location  \
# 0      Anglia Ruskin University  \t\tCambridge (England), England\r\n
# ...

# %%
dataV2.to_excel('TourismPrograms_UK.xlsx', index=False)
